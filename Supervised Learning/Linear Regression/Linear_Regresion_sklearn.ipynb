# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
#Load the dataset
df = pd.read_csv(r"C:\Users\garv\OneDrive\Desktop\UNITY\Machine Learning\Datasets\salary_data.csv")

# Extract Features (X) and Target Variable (Y)
X = df.iloc[:, :-1].values  # YearsExperience
Y = df.iloc[:, -1].values   # Salary

# Split the dataset into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
#create a Linear Regression model
model = LinearRegression()

# Fit the model to the training data
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
# Compute Mean Squared Error (MSE)
mse = mean_squared_error(Y_test, y_pred)

# Print Model Parameters & MSE
print(f"Trained Coefficient (W): {model.coef_[0]}")
print(f"Trained Intercept (b): {model.intercept_}")
print(f"Mean Squared Error: {mse}")
# Out:
# Trained Coefficient (W): 4845.634540059346
# Trained Intercept (b): 34044.790889465876
# Mean Squared Error: 25432566.01846409

# %%
# Plot Training Data
plt.scatter(X_train, Y_train, color="blue", label="Training Data")

# Plot Regression Line
plt.plot(X_train, model.predict(X_train), color="red", label="Regression Line")

# Labels and Title
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.title("Linear Regression: Salary vs Experience")
plt.legend()

# Show Plot
plt.show()
